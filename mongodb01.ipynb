# %% [markdown]
# <a href="https://colab.research.google.com/github/revtinath/my_python_projects/blob/main/mongodb01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pymongo

# %%
from pymongo import MongoClient

# %%
client=MongoClient("mongodb+srv://Rohit:Rohit123@clusterohit.fjvpqf4.mongodb.net/?appName=clusterohit")

# %%
db=client["rohit"]

# %%
con=db["students"]

# %%
for doc in con.find():
  print(doc)
# Out:
# {'_id': '10048', 'name': 'Sarita Rani', 'age': 23, 'course': 'Electrical Engineering', 'grade': 'C+'}
# {'_id': '10022', 'name': 'Ritu Agarwal', 'age': 22, 'course': 'Mechanical Engineering', 'grade': 'A'}
# {'_id': '10040', 'name': 'Radhika Nair', 'age': 23, 'course': 'Information Technology', 'grade': 'A-'}
# {'_id': '10028', 'name': 'Seema Rani', 'age': 23, 'course': 'Electrical Engineering', 'grade': 'C+'}
# {'_id': '10030', 'name': 'Alka Sharma', 'age': 22, 'course': 'Information Technology', 'grade': 'A+'}
# {'_id': '10027', 'name': 'Harish Kumar', 'age': 20, 'course': 'Mechanical Engineering', 'grade': 'A'}
# {'_id': '10016', 'name': 'Shweta Kulkarni', 'age': 20, 'course': 'Computer Science', 'grade': 'A+'}
# {'_id': '10023', 'name': 'Ashok Singh', 'age': 20, 'course': 'Electrical Engineering', 'grade': 'B'}
# {'_id': '10037', 'name': 'Ajay Kumar', 'age': 21, 'course': 'Mechanical Engineering', 'grade': 'C+'}
# ...

# %%
for doc in con.find().sort("_id", 1):
    print(doc)
# Out:
# {'_id': '10001', 'name': 'Rohit Sharma', 'age': 21, 'course': 'Computer Science', 'grade': 'A'}
# {'_id': '10002', 'name': 'Priya Singh', 'age': 22, 'course': 'Mechanical Engineering', 'grade': 'B+'}
# {'_id': '10003', 'name': 'Amit Patel', 'age': 20, 'course': 'Electrical Engineering', 'grade': 'A-'}
# {'_id': '10004', 'name': 'Sneha Verma', 'age': 23, 'course': 'Civil Engineering', 'grade': 'B'}
# {'_id': '10005', 'name': 'Karan Mehta', 'age': 21, 'course': 'Information Technology', 'grade': 'A'}
# {'_id': '10006', 'name': 'Neha Gupta', 'age': 22, 'course': 'Computer Science', 'grade': 'A+'}
# {'_id': '10007', 'name': 'Vikas Yadav', 'age': 24, 'course': 'Mechanical Engineering', 'grade': 'C+'}
# {'_id': '10008', 'name': 'Anjali Deshmukh', 'age': 20, 'course': 'Electrical Engineering', 'grade': 'B+'}
# {'_id': '10009', 'name': 'Suresh Kumar', 'age': 23, 'course': 'Civil Engineering', 'grade': 'A-'}
# ...
