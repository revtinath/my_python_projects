# %%
pip install pymongo
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 30.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.1/331.1 kB 22.1 MB/s eta 0:00:00
# ...

# %%
from pymongo import MongoClient

# %%
client=MongoClient("mongodb+srv://malti:malti@clusterabhishek.n20fktb.mongodb.net/?appName=Clusterabhishek")

# %%
db=client["abhidb"]
coll=db["employees"]

# %%
for doc in coll.find():
  print(doc)
# Out:
# {'_id': '12011', 'name': 'Arjun Reddy', 'dept': 'Sales', 'salary': 31000}
# {'_id': '12005', 'name': 'Karan Mehta', 'dept': 'Marketing', 'salary': 28000}
# {'_id': '12009', 'name': 'Suresh Kumar', 'dept': 'Finance', 'salary': 33000}
# {'_id': '12008', 'name': 'Anjali Deshmukh', 'dept': 'IT', 'salary': 45000}
# {'_id': '12015', 'name': 'Manish Tiwari', 'dept': 'Marketing', 'salary': 30000}
# {'_id': '12012', 'name': 'Pooja Nair', 'dept': 'HR', 'salary': 26000}
# {'_id': '12014', 'name': 'Divya Iyer', 'dept': 'Finance', 'salary': 34000}
# {'_id': '12007', 'name': 'Vikas Yadav', 'dept': 'HR', 'salary': 27000}
# {'_id': '12018', 'name': 'Rachna Pandey', 'dept': 'IT', 'salary': 46000}
# {'_id': '12016', 'name': 'Shweta Kulkarni', 'dept': 'Sales', 'salary': 28000}
# {'_id': '12020', 'name': 'Kavita Sharma', 'dept': 'Marketing', 'salary': 32000}
# {'_id': '12010', 'name': 'Meena Joshi', 'dept': 'Marketing', 'salary': 29000}
# ...

# %%
for doc in coll.find().sort("_id", 1):
    print(doc)
# Out:
# {'_id': '12001', 'name': 'rohit mourya', 'dept': 'sales', 'salary': 25000}
# {'_id': '12002', 'name': 'Priya Singh', 'dept': 'HR', 'salary': 30000}
# {'_id': '12003', 'name': 'Amit Patel', 'dept': 'IT', 'salary': 40000}
# {'_id': '12004', 'name': 'Sneha Verma', 'dept': 'Finance', 'salary': 35000}
# {'_id': '12005', 'name': 'Karan Mehta', 'dept': 'Marketing', 'salary': 28000}
# {'_id': '12006', 'name': 'Neha Gupta', 'dept': 'Sales', 'salary': 32000}
# {'_id': '12007', 'name': 'Vikas Yadav', 'dept': 'HR', 'salary': 27000}
# {'_id': '12008', 'name': 'Anjali Deshmukh', 'dept': 'IT', 'salary': 45000}
# {'_id': '12009', 'name': 'Suresh Kumar', 'dept': 'Finance', 'salary': 33000}
# {'_id': '12010', 'name': 'Meena Joshi', 'dept': 'Marketing', 'salary': 29000}
# {'_id': '12011', 'name': 'Arjun Reddy', 'dept': 'Sales', 'salary': 31000}
# {'_id': '12012', 'name': 'Pooja Nair', 'dept': 'HR', 'salary': 26000}
# {'_id': '12013', 'name': 'Ravi Shankar', 'dept': 'IT', 'salary': 42000}
# ...

# %%
print(db.list_collection_names())
# Out:
# ['employees']

# %%
new_collection_name = "workers"
db.create_collection(new_collection_name)
print(f"Collection '{new_collection_name}' created successfully.")
# Out:
# Collection 'workers' created successfully.
